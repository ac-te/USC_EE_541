# %% [markdown]
# ## Homework #1 – Tools and Fundamentals
# ### Name: Tejas Harishchandra Acharya
# ### Date: 02-08-2025
# ### ID: 9933-6984-15

# %%
# Imports for HW_1
import random
import matplotlib.pyplot as plt

# %%
# Constants for Q_1
P_HEAD = 0.7

# %%
def is_head():
    return random.uniform(0, 1) < P_HEAD

# %%
def get_trials(num_trials):
    return [is_head() for i in range(num_trials)]

# %%
def get_longest_run_heads(trials):
    max_run = 0
    curr_run = 1 if trials[0] else 0

    for i in range(1, len(trials)):
        if trials[i]:
            if trials[i] == trials[i - 1]:
                curr_run += 1
            else:
                curr_run = 1
        else:
            max_run = max(max_run, curr_run)
            curr_run = 0
    return max_run

# %% [markdown]
# #### 1 (a)

# %%
num_trials = 50
trials = get_trials(num_trials)
num_heads = sum(trials)
print(f"For 50 trials, the number of Heads = {num_heads}")
# Out:
# For 50 trials, the number of Heads = 31

# %%
longest_run_heads = get_longest_run_heads(trials)
print(f"For 50 trials, the longest run of heads = {longest_run_heads}")
# Out:
# For 50 trials, the longest run of heads = 6

# %%
num_repeats = 20

num_heads_list = [sum(get_trials(num_trials)) for i in range(num_repeats)]

plt.figure()
plt.hist(num_heads_list)
plt.xlabel("Number of Heads")
plt.ylabel("Count")
plt.title(f"Histogram of Num. Heads for {num_repeats} repeats of flipping the coin {num_trials} times")
plt.show()

# %%
num_repeats = 100

num_heads_list = [sum(get_trials(num_trials)) for i in range(num_repeats)]

plt.figure()
plt.hist(num_heads_list)
plt.xlabel("Number of Heads")
plt.ylabel("Count")
plt.title(f"Histogram of Num. Heads for {num_repeats} repeats of flipping the coin {num_trials} times")
plt.show()

# %%
num_repeats = 200

num_heads_list = [sum(get_trials(num_trials)) for i in range(num_repeats)]

plt.figure()
plt.hist(num_heads_list)
plt.xlabel("Number of Heads")
plt.ylabel("Count")
plt.title(f"Histogram of Num. Heads for {num_repeats} repeats of flipping the coin {num_trials} times")
plt.show()

# %%
num_repeats = 1000

num_heads_list = [sum(get_trials(num_trials)) for i in range(num_repeats)]

plt.figure()
plt.hist(num_heads_list)
plt.xlabel("Number of Heads")
plt.ylabel("Count")
plt.title(f"Histogram of Num. Heads for {num_repeats} repeats of flipping the coin {num_trials} times")
plt.show()

# %%
print(f"X-Axis limit: {min(num_heads_list)} to {max(num_heads_list)}")
# Out:
# X-Axis limit: 25 to 44

# %% [markdown]
# #### 1 (b)

# %%
num_trials = 500

# %%
num_repeats = 20

longest_heads_run_list = [get_longest_run_heads(get_trials(num_trials)) for i in range(num_repeats)]

plt.figure()
plt.hist(num_heads_list)
plt.xlabel("Longest Run of Heads")
plt.ylabel("Count")
plt.title(f"Histogram of Longest Run of Heads for {num_repeats} repeats of flipping the coin {num_trials} times")
plt.show()

# %%
num_repeats = 100

longest_heads_run_list = [get_longest_run_heads(get_trials(num_trials)) for i in range(num_repeats)]

plt.figure()
plt.hist(num_heads_list)
plt.xlabel("Longest Run of Heads")
plt.ylabel("Count")
plt.title(f"Histogram of Longest Run of Heads for {num_repeats} repeats of flipping the coin {num_trials} times")
plt.show()

# %%
num_repeats = 200

longest_heads_run_list = [get_longest_run_heads(get_trials(num_trials)) for i in range(num_repeats)]

plt.figure()
plt.hist(num_heads_list)
plt.xlabel("Longest Run of Heads")
plt.ylabel("Count")
plt.title(f"Histogram of Longest Run of Heads for {num_repeats} repeats of flipping the coin {num_trials} times")
plt.show()

# %%
num_repeats = 1000

longest_heads_run_list = [get_longest_run_heads(get_trials(num_trials)) for i in range(num_repeats)]

plt.figure()
plt.hist(num_heads_list)
plt.xlabel("Longest Run of Heads")
plt.ylabel("Count")
plt.title(f"Histogram of Longest Run of Heads for {num_repeats} repeats of flipping the coin {num_trials} times")
plt.show()
